# %%
"""Practise Dictionary """
# Dictionary
d = {1: "pankaj", 2: "sagar", 3: "python", 4: "programming"}
print(d[1], type(d))
d = {}
d['alpha'] = "A"
d['alpha1'] = "B"
d2 = {'alpha2': "C", 'alpha3': "D"}
d.update(d2)
print(d)
del (d['alpha1'])
print(d.keys())
# Out:
# pankaj <class 'dict'>
# {'alpha': 'A', 'alpha1': 'B', 'alpha2': 'C', 'alpha3': 'D'}
# dict_keys(['alpha', 'alpha2', 'alpha3'])

# %%
"""Tuple"""
t = (1, 2, 3, 4, 5)
print(t, type(t))
t = (1, 2, 3, 4, 5)
print(t[0])
t = (1, 2, 3, 4, 5)
print(t[0:3])
# Out:
# (1, 2, 3, 4, 5) <class 'tuple'>
# 1
# (1, 2, 3)

# %%
s = {1, 2, 3, 4, 5}

print(s, type(s))

# add element
s.add(6)
print(s)

# remove element
s.remove(1)
print(s)

# discard element
s.discard(2)
print(s)

# discard element which is not present
s.discard(10)
print(s)

# clear the set
s.clear()
print(s)
# Out:
# {1, 2, 3, 4, 5} <class 'set'>
# {1, 2, 3, 4, 5, 6}
# {2, 3, 4, 5, 6}
# {3, 4, 5, 6}
# {3, 4, 5, 6}
# set()

# %%
"""Write a function for basic math operations like add multiply substract divide and use this in your program, take 2 number input from user."""
def add(a, b):
    return a + b

def multiply(a, b):
    return a * b

def substract(a, b):
    return a - b

def divide(a, b):
    return a / b

# Take input from user
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))

# Use the functions
print("Addition:", add(num1, num2))
print("Multiplication:", multiply(num1, num2))
print("Subtraction:", substract(num1, num2))
print("Division:", divide(num1, num2))
# Out:
# Addition: 3.0
# Multiplication: 2.0
# Subtraction: -1.0
# Division: 0.5

# %%
def palindrome(n):
    rev = n[::-1]
    if n == rev:
        return "Palindrome"
    else:
        return "Not Palindrome"
    
print(palindrome('123'))
print(palindrome('121'))
# Out:
# Not Palindrome
# Palindrome
